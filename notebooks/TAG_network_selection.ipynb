# %% [markdown]
# ### TAG Network Selection for...
# ##Efficiently Identifying Task Groupings for Multi-Task Learning
#
# Licensed under the Apache License, Version 2.0

# %% [markdown]
# ### CelebA

# %%
# TAG average inter-task affinities.
revised_integrals = {'5_o_Clock_Shadow': {'5_o_Clock_Shadow': 239.72068958020347, 'Black_Hair': -83.33548677967012, 'Blond_Hair': -86.0517490934864, 'Brown_Hair': -82.42068049883574, 'Goatee': -81.97442569877438, 'Mustache': -86.02419971908775, 'No_Beard': -49.037597943401195, 'Rosy_Cheeks': -87.3711143500207, 'Wearing_Hat': -86.77026014855653}, 'Black_Hair': {'5_o_Clock_Shadow': -188.15657486387036, 'Black_Hair': 378.8511885198165, 'Blond_Hair': -184.52892836169266, 'Brown_Hair': -147.50232270522932, 'Goatee': -189.464933472838, 'Mustache': -190.9978380658358, 'No_Beard': -185.28495779578083, 'Rosy_Cheeks': -190.6576875894878, 'Wearing_Hat': -189.41933750548824}, 'Blond_Hair': {'5_o_Clock_Shadow': -121.05393759410462, 'Black_Hair': -109.58362502552134, 'Blond_Hair': 310.7120317369794, 'Brown_Hair': -106.02204254857973, 'Goatee': -122.62230998931582, 'Mustache': -124.40291642298871, 'No_Beard': -117.20407488470592, 'Rosy_Cheeks': -120.55632616819761, 'Wearing_Hat': -123.25851616996826}, 'Brown_Hair': {'5_o_Clock_Shadow': -143.72124825753016, 'Black_Hair': -112.17930410506702, 'Blond_Hair': -139.84807280830086, 'Brown_Hair': 321.53891335979023, 'Goatee': -145.42740587751805, 'Mustache': -146.78348353101595, 'No_Beard': -142.3971373230815, 'Rosy_Cheeks': -146.29884678475298, 'Wearing_Hat': -146.22726918591053}, 'Goatee': {'5_o_Clock_Shadow': -85.53234687179813, 'Black_Hair': -92.21160616332925, 'Blond_Hair': -95.75043274633258, 'Brown_Hair': -91.74112249406916, 'Goatee': 238.42495844470608, 'Mustache': -65.42735927466887, 'No_Beard': -45.95103369426986, 'Rosy_Cheeks': -98.59883005339663, 'Wearing_Hat': -95.6828851878095}, 'Mustache': {'5_o_Clock_Shadow': -30.223281466637463, 'Black_Hair': -32.697193679549336, 'Blond_Hair': -34.78380316865219, 'Brown_Hair': -33.47520370724056, 'Goatee': -0.8396637863075016, 'Mustache': 178.66788767657505, 'No_Beard': -15.271524701599517, 'Rosy_Cheeks': -35.20658096923006, 'Wearing_Hat': -34.37035408412552}, 'No_Beard': {'5_o_Clock_Shadow': -109.47881478244865, 'Black_Hair': -147.50179136978863, 'Blond_Hair': -152.39464713301385, 'Brown_Hair': -148.48881711332825, 'Goatee': -127.31550988605389, 'Mustache': -147.13584310859744, 'No_Beard': 291.8495619980659, 'Rosy_Cheeks': -157.47676146469695, 'Wearing_Hat': -156.15812124227463}, 'Rosy_Cheeks': {'5_o_Clock_Shadow': -74.97883839974561, 'Black_Hair': -74.24941175274341, 'Blond_Hair': -72.04941829851619, 'Brown_Hair': -73.83159368156338, 'Goatee': -76.45193929878833, 'Mustache': -76.49830443422142, 'No_Beard': -75.21144504121774, 'Rosy_Cheeks': 240.390333377952, 'Wearing_Hat': -77.00375527569419}, 'Wearing_Hat': {'5_o_Clock_Shadow': -109.37079668739855, 'Black_Hair': -100.84965267237799, 'Blond_Hair': -113.52459033628551, 'Brown_Hair': -110.64525748395384, 'Goatee': -110.26379082868624, 'Mustache': -116.10172294652246, 'No_Beard': -106.51167682200729, 'Rosy_Cheeks': -119.35220036279986, 'Wearing_Hat': 374.6323404450723}}

# %%
# CS Grouping.
revised_integrals = {'5_o_Clock_Shadow': {'5_o_Clock_Shadow': 22.00000022440799, 'Black_Hair': 0.25081617948664875, 'Blond_Hair': 0.2061718919411787, 'Brown_Hair': 0.2881746112139813, 'Goatee': 0.625541867401377, 'Mustache': 0.38242295235962176, 'No_Beard': 2.1118374600002627, 'Rosy_Cheeks': 0.1492321557089947, 'Wearing_Hat': 0.29801101447452005}, 'Black_Hair': {'5_o_Clock_Shadow': 0.25081617948664875, 'Black_Hair': 22.00000018551502, 'Blond_Hair': 0.42110319038773486, 'Brown_Hair': 1.369120119153668, 'Goatee': 0.24038168565267032, 'Mustache': 0.15441270535298604, 'No_Beard': 0.3694005647915243, 'Rosy_Cheeks': 0.13147151774684296, 'Wearing_Hat': 0.2561181352237544}, 'Blond_Hair': {'5_o_Clock_Shadow': 0.2061718919411787, 'Black_Hair': 0.42110319038773486, 'Blond_Hair': 22.000000177970726, 'Brown_Hair': 0.5411562459181858, 'Goatee': 0.17836285116075049, 'Mustache': 0.10293958113919395, 'No_Beard': 0.3570151728601598, 'Rosy_Cheeks': 0.2991049753957141, 'Wearing_Hat': 0.1989976827574676}, 'Brown_Hair': {'5_o_Clock_Shadow': 0.2881746112139813, 'Black_Hair': 1.369120119153668, 'Blond_Hair': 0.5411562459181858, 'Brown_Hair': 22.000000190247775, 'Goatee': 0.2258797879312138, 'Mustache': 0.1033378763023164, 'No_Beard': 0.3621806593964234, 'Rosy_Cheeks': 0.13119629044801062, 'Wearing_Hat': 0.16213748738052247}, 'Goatee': {'5_o_Clock_Shadow': 0.625541867401377, 'Black_Hair': 0.24038168565267032, 'Blond_Hair': 0.17836285116075049, 'Brown_Hair': 0.2258797879312138, 'Goatee': 22.00000020739817, 'Mustache': 2.885253067680917, 'No_Beard': 1.957515441464863, 'Rosy_Cheeks': 0.08417127602449773, 'Wearing_Hat': 0.36185996873670195}, 'Mustache': {'5_o_Clock_Shadow': 0.38242295235962176, 'Black_Hair': 0.15441270535298604, 'Blond_Hair': 0.10293958113919395, 'Brown_Hair': 0.1033378763023164, 'Goatee': 2.885253067680917, 'Mustache': 22.00000018340637, 'No_Beard': 0.9277471130069601, 'Rosy_Cheeks': 0.11723857216379202, 'Wearing_Hat': 0.24007541606124794}, 'No_Beard': {'5_o_Clock_Shadow': 2.1118374600002627, 'Black_Hair': 0.3694005647915243, 'Blond_Hair': 0.3570151728601598, 'Brown_Hair': 0.3621806593964234, 'Goatee': 1.957515441464863, 'Mustache': 0.9277471130069601, 'No_Beard': 22.000000198166955, 'Rosy_Cheeks': 0.15052633990539294, 'Wearing_Hat': 0.2759176363075264}, 'Rosy_Cheeks': {'5_o_Clock_Shadow': 0.1492321557089947, 'Black_Hair': 0.13147151774684296, 'Blond_Hair': 0.2991049753957141, 'Brown_Hair': 0.13119629044801062, 'Goatee': 0.08417127602449773, 'Mustache': 0.11723857216379202, 'No_Beard': 0.15052633990539294, 'Rosy_Cheeks': 22.00000021428645, 'Wearing_Hat': 0.07270302767988278}, 'Wearing_Hat': {'5_o_Clock_Shadow': 0.29801101447452005, 'Black_Hair': 0.2561181352237544, 'Blond_Hair': 0.1989976827574676, 'Brown_Hair': 0.16213748738052247, 'Goatee': 0.36185996873670195, 'Mustache': 0.24007541606124794, 'No_Beard': 0.2759176363075264, 'Rosy_Cheeks': 0.07270302767988278, 'Wearing_Hat': 22.000000216582542}}

# %% [markdown]
# ### Taskonomy

# %%
# TAG average inter-task affinities.
revised_integrals = {'ss_l': {'ss_l': 11.999321423965947, 'norm_l': 0.04891036220837213, 'depth_l': 0.11537429894122785, 'key_l': 0.00454724706606927, 'edge2d_l': 0.008776140044461892}, 'depth_l': {'ss_l': 0.41355850961858076, 'norm_l': 0.2914147606289435, 'depth_l': 7.3276368896443556, 'key_l': 0.01353652075974951, 'edge2d_l': 0.07395688217092156}, 'norm_l': {'ss_l': 0.13982367687578146, 'norm_l': 1.070989344832557, 'depth_l': 0.22096194178241185, 'key_l': 0.010493772045577332, 'edge2d_l': 0.07645966827511533}, 'key_l': {'ss_l': 0.021098526716001414, 'norm_l': 0.010729013557423, 'depth_l': 0.013365983131803236, 'key_l': 0.7338844180545812, 'edge2d_l': 0.6897358940641894}, 'edge2d_l': {'ss_l': 0.056692022190245474, 'norm_l': 0.03600666458561003, 'depth_l': 0.03668338077695892, 'key_l': 0.30372134710544996, 'edge2d_l': 5.9661909882444615}}

# %%
# CS Grouping.
revised_integrals = {'ss_l': {'ss_l': 9.799051248375491, 'norm_l': 0.24237152135772985, 'depth_l': 0.259569212601681, 'key_l': 0.054060216676064456, 'edge2d_l': 0.08864023100811838}, 'depth_l': {'ss_l': 0.259569212601681, 'norm_l': 0.9115829230192612, 'depth_l': 9.799051266535107, 'key_l': 0.09153054737281137, 'edge2d_l': 0.15646468903944455}, 'norm_l': {'ss_l': 0.24237152135772985, 'norm_l': 9.799051265833779, 'depth_l': 0.9115829230192612, 'key_l': 0.14588496629635408, 'edge2d_l': 0.28013964222462745}, 'key_l': {'ss_l': 0.054060216676064456, 'norm_l': 0.14588496629635408, 'depth_l': 0.09153054737281137, 'key_l': 9.79905053927595, 'edge2d_l': 2.9680815659422954}, 'edge2d_l': {'ss_l': 0.08864023100811838, 'norm_l': 0.28013964222462745, 'depth_l': 0.15646468903944455, 'key_l': 2.9680815659422954, 'edge2d_l': 9.79904991291345}}

# %% [markdown]
# ### Ysdat

# %%
# revised_integrals0 = {'event_0': [{'event_0': 2.9807821044752134,
#    'event_1': -1983.678016090017,
#    'event_2': -2548.6888352904734,
#    'event_3': -3634.430548426674,
#    'event_4': -4216.451688227769,
#    'event_5': -4887.770814829924,
#    'event_6': -8155.837666425177,
#    'event_7': -7556.646218981954,
#    'event_8': -12882.619012121768,
#    'event_9': -11469.292296308855},
#   {'event_0': 0.20935813468585174,
#    'event_1': -1489.0053220934128,
#    'event_2': -2449.010483148529,
#    'event_3': -3886.3502967013465,
#    'event_4': -7237.72200046249,
#    'event_5': -9506.87856959546,
#    'event_6': -19343.182846429776,
#    'event_7': -22340.14800855181,
#    'event_8': -29810.983357266796,
#    'event_9': -26550.719565243857},
#   {'event_0': 1.049575800579677,
#    'event_1': -1691.9608004762742,
#    'event_2': -4894.607748797561,
#    'event_3': -4477.42534907784,
#    'event_4': -7874.36565328458,
#    'event_5': -7586.9948019192925,
#    'event_6': -18481.134068046027,
#    'event_7': -23419.55109443565,
#    'event_8': -28255.897511559837,
#    'event_9': -38027.24014242176},
#   {'event_0': 0.4444897499453676,
#    'event_1': -1566.4771872993526,
#    'event_2': -3759.9163092715835,
#    'event_3': -3882.949796761741,
#    'event_4': -8216.20796283712,
#    'event_5': -10856.458910844454,
#    'event_6': -16333.901453694018,
#    'event_7': -23134.469123900417,
#    'event_8': -25270.3817132264,
#    'event_9': -37681.68829169485},
#   {'event_0': -0.3782219893428598,
#    'event_1': -2855.014530892759,
#    'event_2': -5080.594232514149,
#    'event_3': -6926.965003426619,
#    'event_4': -11329.968062873902,
#    'event_5': -11079.467445033113,
#    'event_6': -17926.091907731505,
#    'event_7': -31898.318072141305,
#    'event_8': -38120.89932739578,
#    'event_9': -41881.16455398519},
#   {'event_0': 0.006513255709425358,
#    'event_1': -1584.807178417216,
#    'event_2': -4186.284667261314,
#    'event_3': -5050.953503806445,
#    'event_4': -9033.617129788938,
#    'event_5': -10152.302733343731,
#    'event_6': -27844.387051840153,
#    'event_7': -26778.802404128346,
#    'event_8': -30611.148637586382,
#    'event_9': -35499.17442822393},
#   {'event_0': 0.9437829948316406,
#    'event_1': -2612.116788929216,
#    'event_2': -3086.8310751126514,
#    'event_3': -3588.208616912522,
#    'event_4': -9400.458120911768,
#    'event_5': -12900.226001889689,
#    'event_6': -22022.75317625111,
#    'event_7': -36198.0541431497,
#    'event_8': -45740.41914812224,
#    'event_9': -39828.77294024771},
#   {'event_0': -0.18689354094542246,
#    'event_1': -2770.978721959072,
#    'event_2': -4044.382283768942,
#    'event_3': -6361.827901905287,
#    'event_4': -10436.030731201172,
#    'event_5': -9221.136737332885,
#    'event_6': -25689.351563140786,
#    'event_7': -34563.14123388351,
#    'event_8': -32907.495866910685,
#    'event_9': -40658.03815546312},
#   {'event_0': 0.318412199968428,
#    'event_1': -2111.992944832549,
#    'event_2': -3221.3444851452277,
#    'event_3': -3472.7304912176664,
#    'event_4': -8129.888038535132,
#    'event_5': -6667.191211770526,
#    'event_6': -21357.589316781112,
#    'event_7': -23817.580715539883,
#    'event_8': -34768.919451856236,
#    'event_9': -37542.777494495625},
#   {'event_0': -0.49247277651246135,
#    'event_1': -2274.0047721161927,
#    'event_2': -3176.7498466912216,
#    'event_3': -5287.737654388108,
#    'event_4': -9342.845361564416,
#    'event_5': -7003.712723699454,
#    'event_6': -19817.468811996347,
#    'event_7': -28707.24562036709,
#    'event_8': -43336.04526629911,
#    'event_9': -33786.93173185734},
#   {'event_0': 0.3925127410904316,
#    'event_1': -2451.8259083004446,
#    'event_2': -2423.855443138463,
#    'event_3': -4439.370118188734,
#    'event_4': -7913.047307933096,
#    'event_5': -11441.627012638286,
#    'event_6': -30491.580729046516,
#    'event_7': -26321.726884816886,
#    'event_8': -33936.665910535594,
#    'event_9': -36149.86751205965},
#   {'event_0': -0.4403498459832248,
#    'event_1': -3228.7176448591736,
#    'event_2': -2691.7466075026136,
#    'event_3': -5068.754221197814,
#    'event_4': -6967.15487309954,
#    'event_5': -12227.511495855535,
#    'event_6': -24897.906506956402,
#    'event_7': -29135.78065486719,
#    'event_8': -32894.18515583349,
#    'event_9': -44348.77920396059},
#   {'event_0': 0.8421101734003056,
#    'event_1': -2007.5820827734435,
#    'event_2': -3368.492014958791,
#    'event_3': -3815.2738318856304,
#    'event_4': -7837.807517865199,
#    'event_5': -8992.85540723425,
#    'event_6': -16415.717913009365,
#    'event_7': -31959.375345700686,
#    'event_8': -31820.181235566226,
#    'event_9': -32190.331714359792}],
#  'event_1': [{'event_0': 346.9310652990667,
#    'event_1': -216.54462452401017,
#    'event_2': -997.6304996115327,
#    'event_3': -977.2478194374422,
#    'event_4': -1798.2273645820267,
#    'event_5': -2163.1996332754297,
#    'event_6': -3456.488717415827,
#    'event_7': -3284.2869945930365,
#    'event_8': -6523.433549830448,
#    'event_9': -5406.894728246481},
#   {'event_0': 220.28548429644326,
#    'event_1': -223.03998444024032,
#    'event_2': -1239.5838984291697,
#    'event_3': -2252.754048187276,
#    'event_4': -4315.746906911293,
#    'event_5': -5855.042785155804,
#    'event_6': -12797.581024970908,
#    'event_7': -12344.808198222969,
#    'event_8': -18057.449899608382,
#    'event_9': -17526.62721448683},
#   {'event_0': 254.7597744959233,
#    'event_1': -305.46576528724415,
#    'event_2': -2910.0314446196467,
#    'event_3': -2048.2607694811077,
#    'event_4': -3563.9260630970552,
#    'event_5': -5270.410652360892,
#    'event_6': -10337.104640369966,
#    'event_7': -13949.461360941412,
#    'event_8': -20918.632475923052,
#    'event_9': -22740.484369933758},
#   {'event_0': 269.5421775369819,
#    'event_1': -318.82562509671914,
#    'event_2': -1799.0866530911508,
#    'event_3': -1825.005791431337,
#    'event_4': -4691.117099451581,
#    'event_5': -6645.3864158920705,
#    'event_6': -10276.650154490484,
#    'event_7': -14478.881788979676,
#    'event_8': -16527.891648260003,
#    'event_9': -22588.786579442465},
#   {'event_0': 393.9085697126514,
#    'event_1': -339.75251304763043,
#    'event_2': -2231.9390561762125,
#    'event_3': -3012.6736295504825,
#    'event_4': -5837.206296345067,
#    'event_5': -4608.392204825333,
#    'event_6': -10525.647991711072,
#    'event_7': -18380.877762441556,
#    'event_8': -19157.508066733048,
#    'event_9': -23888.82494107945},
#   {'event_0': 217.81950482546185,
#    'event_1': -354.98458944906406,
#    'event_2': -2595.4296540588225,
#    'event_3': -2952.6588992778397,
#    'event_4': -4817.532743418935,
#    'event_5': -6256.6508521933565,
#    'event_6': -19003.87990716248,
#    'event_7': -16134.929866139973,
#    'event_8': -18721.912853010686,
#    'event_9': -23227.11462786817},
#   {'event_0': 390.0500309060564,
#    'event_1': -433.82289727528894,
#    'event_2': -1012.0362155393664,
#    'event_3': -1646.9055215830563,
#    'event_4': -5455.749925728544,
#    'event_5': -6460.9821598924045,
#    'event_6': -10308.869448083591,
#    'event_7': -19784.895323405424,
#    'event_8': -21847.402397215836,
#    'event_9': -20452.854846543847},
#   {'event_0': 378.0510891140914,
#    'event_1': -386.50773088450194,
#    'event_2': -1749.2841884783247,
#    'event_3': -3326.162387567554,
#    'event_4': -5334.9620772159005,
#    'event_5': -4271.534588330687,
#    'event_6': -13918.12926675391,
#    'event_7': -17730.558545170174,
#    'event_8': -18444.342675396776,
#    'event_9': -18332.80019234484},
#   {'event_0': 165.55205592958947,
#    'event_1': -333.52771969292115,
#    'event_2': -1703.0376594022819,
#    'event_3': -2040.0383989641984,
#    'event_4': -5101.745497185414,
#    'event_5': -4841.446581662796,
#    'event_6': -13138.540860874447,
#    'event_7': -12226.28395461035,
#    'event_8': -20108.870391445213,
#    'event_9': -24017.278879921578},
#   {'event_0': 291.8597687589216,
#    'event_1': -400.0248992599526,
#    'event_2': -1750.435827961118,
#    'event_3': -2604.3541397635386,
#    'event_4': -5400.922621078692,
#    'event_5': -3902.5376940149017,
#    'event_6': -13478.45338538563,
#    'event_7': -18792.699755170524,
#    'event_8': -26996.678219292113,
#    'event_9': -21439.88191774824},
#   {'event_0': 370.52511865385554,
#    'event_1': -496.55473717867227,
#    'event_2': -1190.6629400178203,
#    'event_3': -2159.3932979063093,
#    'event_4': -4216.5430706254465,
#    'event_5': -5879.559559709443,
#    'event_6': -17637.928888916656,
#    'event_7': -15762.425613903932,
#    'event_8': -17374.998611890736,
#    'event_9': -21106.36534362953},
#   {'event_0': 336.7693274790845,
#    'event_1': -452.0506365217874,
#    'event_2': -1291.7100199251345,
#    'event_3': -2472.636276605561,
#    'event_4': -3609.2608359229207,
#    'event_5': -6456.59004311549,
#    'event_6': -12887.357202164458,
#    'event_7': -15162.711300987585,
#    'event_8': -16378.007452156286,
#    'event_9': -21831.85521403635},
#   {'event_0': 233.22727653923934,
#    'event_1': -408.4717166580239,
#    'event_2': -1846.8135468227656,
#    'event_3': -2408.053610243509,
#    'event_4': -4238.634204213701,
#    'event_5': -5004.012866533335,
#    'event_6': -11736.720106376439,
#    'event_7': -19574.218996603653,
#    'event_8': -18142.42605214356,
#    'event_9': -16961.786605329336}],
#  'event_2': [{'event_0': 392.0029912971135,
#    'event_1': -871.6249885098164,
#    'event_2': -310.9700956228836,
#    'event_3': -1049.1298141692253,
#    'event_4': -1836.5213108375629,
#    'event_5': -1690.0657128865325,
#    'event_6': -3456.5365846263458,
#    'event_7': -3278.5711718974458,
#    'event_8': -6011.618307279894,
#    'event_9': -4203.158312874829},
#   {'event_0': 422.7935433325179,
#    'event_1': -138.54734515893483,
#    'event_2': -342.0471163872346,
#    'event_3': -1190.050663434927,
#    'event_4': -2618.9981974203756,
#    'event_5': -3653.489218784443,
#    'event_6': -8742.658762518815,
#    'event_7': -8893.684817299129,
#    'event_8': -13285.06069894225,
#    'event_9': -13454.320075167754},
#   {'event_0': 530.9091223569053,
#    'event_1': -44.03691219219697,
#    'event_2': -709.447547381944,
#    'event_3': -948.1226680723074,
#    'event_4': -2567.3396904512338,
#    'event_5': -2341.514333689933,
#    'event_6': -6758.701942423824,
#    'event_7': -8792.22957742183,
#    'event_8': -12481.202678793057,
#    'event_9': -14809.887155698036},
#   {'event_0': 500.6399663289388,
#    'event_1': -90.69777531260891,
#    'event_2': -556.0582032291281,
#    'event_3': -996.3945928083002,
#    'event_4': -2988.18977050581,
#    'event_5': -4308.194330020215,
#    'event_6': -6759.664604006789,
#    'event_7': -9047.06148883489,
#    'event_8': -11475.910482331523,
#    'event_9': -14008.197841894596},
#   {'event_0': 599.4112461320371,
#    'event_1': -452.7727708791498,
#    'event_2': -605.4301628478244,
#    'event_3': -1781.7622768472186,
#    'event_4': -3203.2226071895884,
#    'event_5': -3261.9760279674233,
#    'event_6': -5415.785636951918,
#    'event_7': -10329.616263181833,
#    'event_8': -12245.348279357271,
#    'event_9': -14796.008279404927},
#   {'event_0': 477.50198824824935,
#    'event_1': -189.68261498478762,
#    'event_2': -659.6470533823716,
#    'event_3': -1551.3962608904346,
#    'event_4': -2905.363859854971,
#    'event_5': -3744.038751857487,
#    'event_6': -10849.147249356969,
#    'event_7': -11753.872365576075,
#    'event_8': -13016.119949661213,
#    'event_9': -15228.771947224936},
#   {'event_0': 537.8817101225766,
#    'event_1': -487.9347290579728,
#    'event_2': -427.2056460443131,
#    'event_3': -870.9182265174046,
#    'event_4': -3801.2309926451035,
#    'event_5': -4609.792945641544,
#    'event_6': -8437.437259343664,
#    'event_7': -14691.763673366835,
#    'event_8': -17339.690930424083,
#    'event_9': -16439.409018889502},
#   {'event_0': 488.3303568682332,
#    'event_1': -685.3599955841626,
#    'event_2': -564.9281633181837,
#    'event_3': -2424.8428019075563,
#    'event_4': -4077.647692387498,
#    'event_5': -3044.3534132189006,
#    'event_6': -10631.175812448417,
#    'event_7': -14349.947116481351,
#    'event_8': -15102.986596375313,
#    'event_9': -18062.16114647433},
#   {'event_0': 437.54877866409583,
#    'event_1': -366.5977272899758,
#    'event_2': -504.8682432349899,
#    'event_3': -990.056749378915,
#    'event_4': -3410.077313700999,
#    'event_5': -3168.376529517527,
#    'event_6': -9198.925650238678,
#    'event_7': -9997.786060443386,
#    'event_8': -15845.597502540726,
#    'event_9': -17260.76965652426},
#   {'event_0': 466.6471048290023,
#    'event_1': -360.70773707912986,
#    'event_2': -503.158472116225,
#    'event_3': -1578.9835867043241,
#    'event_4': -3485.764470988996,
#    'event_5': -3027.640512421375,
#    'event_6': -8059.727037084386,
#    'event_7': -13582.28215602439,
#    'event_8': -19190.370546275863,
#    'event_9': -16263.125839834136},
#   {'event_0': 508.6954393161562,
#    'event_1': -705.9639834106125,
#    'event_2': -375.1701984255333,
#    'event_3': -1662.179960804036,
#    'event_4': -3301.642512949746,
#    'event_5': -4818.577531178792,
#    'event_6': -13557.328838513587,
#    'event_7': -10639.533028590087,
#    'event_8': -15761.316844910145,
#    'event_9': -14891.431847920257},
#   {'event_0': 403.80008607398804,
#    'event_1': -1190.7442846823865,
#    'event_2': -422.51849387261495,
#    'event_3': -2110.2508341358716,
#    'event_4': -2847.82203233774,
#    'event_5': -5063.775293545459,
#    'event_6': -10920.44315648517,
#    'event_7': -12978.976747307566,
#    'event_8': -17658.338537141088,
#    'event_9': -23108.13729433876},
#   {'event_0': 457.8188268906802,
#    'event_1': -315.1845834887247,
#    'event_2': -541.6756873243438,
#    'event_3': -1861.1533450329396,
#    'event_4': -3073.8888254190674,
#    'event_5': -3605.534272306547,
#    'event_6': -7309.485717232773,
#    'event_7': -13851.134451918711,
#    'event_8': -12879.668283149638,
#    'event_9': -14179.89189117912}],
#  'event_3': [{'event_0': 374.04186825113976,
#    'event_1': -597.3276085052589,
#    'event_2': -965.8641542036703,
#    'event_3': -370.94724155708235,
#    'event_4': -1501.9304231896485,
#    'event_5': -1782.4465594955002,
#    'event_6': -3537.35756580911,
#    'event_7': -3299.8578089679013,
#    'event_8': -5745.620550915324,
#    'event_9': -4553.802672189677},
#   {'event_0': 417.9991946883716,
#    'event_1': -253.11228153899577,
#    'event_2': -569.7263126923968,
#    'event_3': -620.571711933206,
#    'event_4': -2903.8009443308115,
#    'event_5': -3323.493335854037,
#    'event_6': -8126.651170785658,
#    'event_7': -8890.39392336147,
#    'event_8': -12613.868428628273,
#    'event_9': -13208.240909626478},
#   {'event_0': 420.86371414304705,
#    'event_1': -249.08626974411214,
#    'event_2': -2064.759261964813,
#    'event_3': -723.0110070336208,
#    'event_4': -2957.6482351308114,
#    'event_5': -3767.230060407182,
#    'event_6': -7288.326338520199,
#    'event_7': -11849.45931662412,
#    'event_8': -15344.24066378376,
#    'event_9': -18688.127928405924},
#   {'event_0': 446.67247496877746,
#    'event_1': -202.7485530676804,
#    'event_2': -1258.0605972970875,
#    'event_3': -664.3338785897403,
#    'event_4': -3050.538718568997,
#    'event_5': -4702.004740682487,
#    'event_6': -6758.123673967176,
#    'event_7': -10663.945309996918,
#    'event_8': -12770.885771603724,
#    'event_9': -15778.363241360881},
#   {'event_0': 586.1328232131918,
#    'event_1': -333.3412955126425,
#    'event_2': -1326.0432765490111,
#    'event_3': -1055.011650771294,
#    'event_4': -2981.8580811855986,
#    'event_5': -4172.927027768663,
#    'event_6': -5289.760432080647,
#    'event_7': -13603.44618086427,
#    'event_8': -12402.970032116249,
#    'event_9': -17397.746404487632},
#   {'event_0': 392.5611293722638,
#    'event_1': -336.3876682191383,
#    'event_2': -1710.0899414628198,
#    'event_3': -784.6389793035551,
#    'event_4': -2926.515333921578,
#    'event_5': -3745.6486967792666,
#    'event_6': -12170.898137130145,
#    'event_7': -12958.036264346963,
#    'event_8': -16059.425995894297,
#    'event_9': -17207.45485657469},
#   {'event_0': 478.5040881940387,
#    'event_1': -602.3192524346779,
#    'event_2': -815.6026486086407,
#    'event_3': -632.2397641497336,
#    'event_4': -4288.256352442145,
#    'event_5': -5664.199763721056,
#    'event_6': -8971.097280347129,
#    'event_7': -15567.001007961164,
#    'event_8': -18705.595705828327,
#    'event_9': -17298.30742102595},
#   {'event_0': 526.964336405276,
#    'event_1': -623.6283604867189,
#    'event_2': -1139.4485053615617,
#    'event_3': -1058.6504251437552,
#    'event_4': -4223.747781643404,
#    'event_5': -3305.226406988509,
#    'event_6': -9963.64819168732,
#    'event_7': -13508.537661785218,
#    'event_8': -13316.850958821651,
#    'event_9': -18503.222869562665},
#   {'event_0': 445.77345801541816,
#    'event_1': -357.09332770249966,
#    'event_2': -981.1795350322573,
#    'event_3': -599.7735459535453,
#    'event_4': -3534.4856625904868,
#    'event_5': -2966.8144478384907,
#    'event_6': -9462.596761948793,
#    'event_7': -11501.398665986351,
#    'event_8': -16866.14855067936,
#    'event_9': -16866.657376026546},
#   {'event_0': 425.37681531972623,
#    'event_1': -422.2736307579701,
#    'event_2': -973.0291671953177,
#    'event_3': -864.5449090692315,
#    'event_4': -4384.362382863763,
#    'event_5': -3220.6110537271175,
#    'event_6': -8783.346753258093,
#    'event_7': -13010.288535691308,
#    'event_8': -19786.503278026423,
#    'event_9': -15796.410065291746},
#   {'event_0': 530.9382963806312,
#    'event_1': -548.9900304138503,
#    'event_2': -544.644797993457,
#    'event_3': -845.1346281256888,
#    'event_4': -3119.343030684264,
#    'event_5': -4648.508603491495,
#    'event_6': -13890.779809976815,
#    'event_7': -12796.467805747283,
#    'event_8': -14950.898369015675,
#    'event_9': -15537.842583643798},
#   {'event_0': 519.7982543785114,
#    'event_1': -609.1475241953933,
#    'event_2': -577.0196264872714,
#    'event_3': -899.7672904007077,
#    'event_4': -2318.6766366132592,
#    'event_5': -4395.192881106079,
#    'event_6': -9866.865476197769,
#    'event_7': -12212.755125632752,
#    'event_8': -13771.464612515267,
#    'event_9': -17877.143663321265},
#   {'event_0': 438.83420671377905,
#    'event_1': -697.1967300154716,
#    'event_2': -1574.2490024516592,
#    'event_3': -721.5874463679597,
#    'event_4': -3738.3126757964683,
#    'event_5': -3784.386520585989,
#    'event_6': -8102.9277455087085,
#    'event_7': -14187.25901946621,
#    'event_8': -16300.58751489234,
#    'event_9': -12828.518209782796}],
#  'event_4': [{'event_0': 492.8087004977143,
#    'event_1': -184.6576816015669,
#    'event_2': -631.4360834732456,
#    'event_3': -507.5725268597991,
#    'event_4': -577.5116860643615,
#    'event_5': -1370.0014563974512,
#    'event_6': -3117.2020226544914,
#    'event_7': -2714.2450087777584,
#    'event_8': -4584.409277307705,
#    'event_9': -3861.253055678265},
#   {'event_0': 527.7929782617123,
#    'event_1': 25.16698181472737,
#    'event_2': -318.54972258640396,
#    'event_3': -858.7899344737135,
#    'event_4': -1300.6226054764795,
#    'event_5': -3039.932012670622,
#    'event_6': -7718.881134035704,
#    'event_7': -6973.751490835754,
#    'event_8': -10638.839332700714,
#    'event_9': -10235.717507810416},
#   {'event_0': 492.8745768389364,
#    'event_1': -63.62726707158126,
#    'event_2': -1628.5969477375654,
#    'event_3': -1132.0421449405947,
#    'event_4': -1379.2952506811291,
#    'event_5': -3315.196149730933,
#    'event_6': -7103.518559012825,
#    'event_7': -8077.239171926745,
#    'event_8': -12995.33727250387,
#    'event_9': -15293.494245474107},
#   {'event_0': 553.4294389239133,
#    'event_1': -22.633027104255078,
#    'event_2': -766.3450174757188,
#    'event_3': -767.9569301455041,
#    'event_4': -1537.8704684800675,
#    'event_5': -3723.5822192014366,
#    'event_6': -5639.120272338548,
#    'event_7': -8428.235127268814,
#    'event_8': -9765.124397252803,
#    'event_9': -13126.194349474168},
#   {'event_0': 635.4570760251344,
#    'event_1': -274.22438834282985,
#    'event_2': -965.1143189474667,
#    'event_3': -1280.226325788523,
#    'event_4': -1769.4262806449342,
#    'event_5': -3088.5127090782,
#    'event_6': -5398.344869100515,
#    'event_7': -9742.812445332684,
#    'event_8': -10637.613047502173,
#    'event_9': -14216.620940461245},
#   {'event_0': 477.8581464822523,
#    'event_1': -42.85311506802017,
#    'event_2': -1208.352259413151,
#    'event_3': -1452.0456221973488,
#    'event_4': -1476.5170620495255,
#    'event_5': -3830.3237430442346,
#    'event_6': -10405.580554721864,
#    'event_7': -10104.85634528433,
#    'event_8': -11288.335596269822,
#    'event_9': -13218.639156962314},
#   {'event_0': 617.0425451083447,
#    'event_1': -371.41625917489756,
#    'event_2': -509.14461195938236,
#    'event_3': -671.9145305763705,
#    'event_4': -1716.3515952252963,
#    'event_5': -3636.078347333772,
#    'event_6': -6857.465916631102,
#    'event_7': -11399.812692557107,
#    'event_8': -14404.419476841998,
#    'event_9': -13748.599564359572},
#   {'event_0': 600.3026724988082,
#    'event_1': -188.77375064559496,
#    'event_2': -563.4505701190218,
#    'event_3': -1932.4673524929156,
#    'event_4': -1802.4508895273282,
#    'event_5': -2382.3111982670976,
#    'event_6': -8777.981581199827,
#    'event_7': -11221.45004552806,
#    'event_8': -11617.505935702738,
#    'event_9': -13500.379046743003},
#   {'event_0': 557.7855347961266,
#    'event_1': -100.58299435092394,
#    'event_2': -621.1788183497632,
#    'event_3': -678.5003402790059,
#    'event_4': -1537.1627488724516,
#    'event_5': -2164.860381979955,
#    'event_6': -8087.56309929795,
#    'event_7': -7546.989161173503,
#    'event_8': -13448.25930913289,
#    'event_9': -13112.479196983997},
#   {'event_0': 579.027420704759,
#    'event_1': -143.3817692253533,
#    'event_2': -669.1752470572162,
#    'event_3': -1408.2146410178634,
#    'event_4': -1711.637769108369,
#    'event_5': -2136.2673004530857,
#    'event_6': -7341.616545098974,
#    'event_7': -10470.681484552819,
#    'event_8': -14516.435773854493,
#    'event_9': -11861.91166735071},
#   {'event_0': 494.0612735898476,
#    'event_1': -637.5201832027885,
#    'event_2': -698.6707804522177,
#    'event_3': -1938.1372146406202,
#    'event_4': -1489.575688419692,
#    'event_5': -3964.6737944235006,
#    'event_6': -12628.191669519178,
#    'event_7': -11710.751685019864,
#    'event_8': -14064.01624984941,
#    'event_9': -14643.007690649958},
#   {'event_0': 495.9985928272636,
#    'event_1': -856.7608746706344,
#    'event_2': -574.5900025173747,
#    'event_3': -1704.5137149079887,
#    'event_4': -1302.9671926323194,
#    'event_5': -4200.034039965452,
#    'event_6': -9258.525367997137,
#    'event_7': -10287.310738150527,
#    'event_8': -13929.487522906207,
#    'event_9': -17903.2074931788},
#   {'event_0': 519.0839027544956,
#    'event_1': -219.51660914683904,
#    'event_2': -739.4641144131739,
#    'event_3': -1351.7099426424722,
#    'event_4': -1536.9525290161291,
#    'event_5': -3255.521341158649,
#    'event_6': -6157.974924753343,
#    'event_7': -11633.979602923857,
#    'event_8': -13033.969782231046,
#    'event_9': -10642.32548801292}],
#  'event_5': [{'event_0': 525.2963104554675,
#    'event_1': -197.0412932637482,
#    'event_2': -424.381159312456,
#    'event_3': -621.5108594118453,
#    'event_4': -1031.978501037663,
#    'event_5': -712.3278530282298,
#    'event_6': -2289.0335907773397,
#    'event_7': -2559.7862976304505,
#    'event_8': -4431.287051842907,
#    'event_9': -3419.8621390310163},
#   {'event_0': 537.4133616670223,
#    'event_1': -30.10484089688681,
#    'event_2': -268.5466030451256,
#    'event_3': -603.1193991971454,
#    'event_4': -2490.6107197197402,
#    'event_5': -1718.4308229781818,
#    'event_6': -6628.036407911247,
#    'event_7': -6679.415180927185,
#    'event_8': -9532.866937432078,
#    'event_9': -10718.423167501534},
#   {'event_0': 535.5680076719268,
#    'event_1': -109.56630060991904,
#    'event_2': -1276.8478314206982,
#    'event_3': -1069.633748687784,
#    'event_4': -2660.9764976576566,
#    'event_5': -1672.408278257515,
#    'event_6': -7633.519030918913,
#    'event_7': -9355.333478932618,
#    'event_8': -11323.823652793102,
#    'event_9': -15192.175848252504},
#   {'event_0': 565.4287851138379,
#    'event_1': -100.06079110573597,
#    'event_2': -1128.329991981426,
#    'event_3': -718.8504877240639,
#    'event_4': -2525.268968196679,
#    'event_5': -2317.228733573373,
#    'event_6': -5796.132179533091,
#    'event_7': -7322.737218526404,
#    'event_8': -10647.418424200825,
#    'event_9': -14641.046253514733},
#   {'event_0': 619.5533076358905,
#    'event_1': -87.08015506974672,
#    'event_2': -1001.6183680937359,
#    'event_3': -1853.2297720120641,
#    'event_4': -3669.585552165515,
#    'event_5': -1950.9084314060963,
#    'event_6': -5326.4467931231775,
#    'event_7': -10961.338997287696,
#    'event_8': -11455.301058211035,
#    'event_9': -13217.354514254672},
#   {'event_0': 445.24154582987296,
#    'event_1': -71.32380988654188,
#    'event_2': -1317.678579620802,
#    'event_3': -1356.2056453834994,
#    'event_4': -2927.2778210176884,
#    'event_5': -2134.677241768424,
#    'event_6': -10682.140444257439,
#    'event_7': -9737.338663086177,
#    'event_8': -13267.750947356537,
#    'event_9': -16118.918114209111},
#   {'event_0': 607.2187909053691,
#    'event_1': -213.29886042226954,
#    'event_2': -442.15449344141916,
#    'event_3': -642.7882678364831,
#    'event_4': -2735.304532964712,
#    'event_5': -2258.6526547329318,
#    'event_6': -5955.55388583286,
#    'event_7': -10323.06781318244,
#    'event_8': -13751.644516459368,
#    'event_9': -14050.196756678308},
#   {'event_0': 514.9510993106472,
#    'event_1': -235.8296433646535,
#    'event_2': -933.1639041284252,
#    'event_3': -2289.207597141816,
#    'event_4': -4061.6607559384333,
#    'event_5': -1749.878113313609,
#    'event_6': -10305.245322880786,
#    'event_7': -13182.336313643169,
#    'event_8': -14749.45785344743,
#    'event_9': -14387.132509386756},
#   {'event_0': 515.9968244998162,
#    'event_1': -456.95523186931456,
#    'event_2': -870.6840727648397,
#    'event_3': -993.7819605674645,
#    'event_4': -3023.10217679642,
#    'event_5': -1545.2510454272974,
#    'event_6': -8297.503705763129,
#    'event_7': -10370.855255677632,
#    'event_8': -15396.390162815882,
#    'event_9': -14715.690387715818},
#   {'event_0': 495.7052316940988,
#    'event_1': -280.4981688251646,
#    'event_2': -861.9000681178777,
#    'event_3': -1918.5333559581927,
#    'event_4': -3509.41052018814,
#    'event_5': -1740.1274068837402,
#    'event_6': -9081.285882434191,
#    'event_7': -11713.91626993815,
#    'event_8': -20033.623142793112,
#    'event_9': -15064.38707426777},
#   {'event_0': 559.2716339191426,
#    'event_1': -415.42373677251226,
#    'event_2': -426.04773874357926,
#    'event_3': -1288.0153678408442,
#    'event_4': -2519.5055474509086,
#    'event_5': -2231.2441592078826,
#    'event_6': -10775.285049798918,
#    'event_7': -9109.129053839235,
#    'event_8': -12834.219072697357,
#    'event_9': -13195.443657902595},
#   {'event_0': 533.8549115338665,
#    'event_1': -844.513319020509,
#    'event_2': -588.1508015209607,
#    'event_3': -1468.1514094195031,
#    'event_4': -1703.484133727594,
#    'event_5': -2456.0163214575896,
#    'event_6': -8102.85459253106,
#    'event_7': -11237.874150889436,
#    'event_8': -11217.776800440992,
#    'event_9': -18454.753499268867},
#   {'event_0': 513.2438904970023,
#    'event_1': -196.6982981163686,
#    'event_2': -1033.0985788911032,
#    'event_3': -1101.5783340974745,
#    'event_4': -2720.1922435209817,
#    'event_5': -1961.1425192525066,
#    'event_6': -6941.227641969215,
#    'event_7': -12506.651846617848,
#    'event_8': -13020.195000315587,
#    'event_9': -12121.131936220983}],
#  'event_6': [{'event_0': 596.8110292414667,
#    'event_1': 48.943494861833045,
#    'event_2': -171.6980923567544,
#    'event_3': -397.4947663070024,
#    'event_4': -802.4971423483896,
#    'event_5': -762.8007309643302,
#    'event_6': -1270.1666338949065,
#    'event_7': -1737.9078648409507,
#    'event_8': -3060.9860050021193,
#    'event_9': -2896.975776204287},
#   {'event_0': 642.9961443322853,
#    'event_1': 207.7991260818922,
#    'event_2': -73.97399813484334,
#    'event_3': -379.6555926105169,
#    'event_4': -1622.4958493327845,
#    'event_5': -1963.0086302944994,
#    'event_6': -3700.4142012308275,
#    'event_7': -5058.041173229069,
#    'event_8': -8591.047668457033,
#    'event_9': -7820.145864812094},
#   {'event_0': 617.8337241345505,
#    'event_1': 171.95729908667835,
#    'event_2': -952.9021505921532,
#    'event_3': -475.88469027221356,
#    'event_4': -1588.5329492261085,
#    'event_5': -2298.1008108144038,
#    'event_6': -3633.842153273855,
#    'event_7': -7305.021645753715,
#    'event_8': -9280.440007908139,
#    'event_9': -11221.451621243328},
#   {'event_0': 612.5331111717724,
#    'event_1': 72.04489764266125,
#    'event_2': -616.7002233870702,
#    'event_3': -463.2779715880947,
#    'event_4': -2043.797814113887,
#    'event_5': -3188.8535899565286,
#    'event_6': -3545.196600886468,
#    'event_7': -6627.4530446560675,
#    'event_8': -8898.186287291719,
#    'event_9': -12255.107088864943},
#   {'event_0': 637.5587595541646,
#    'event_1': -259.32170647648684,
#    'event_2': -825.0245706553221,
#    'event_3': -1318.2105647610242,
#    'event_4': -2763.830996815926,
#    'event_5': -3161.283150870656,
#    'event_6': -3004.1536738678537,
#    'event_7': -10125.95972224014,
#    'event_8': -9508.243061576302,
#    'event_9': -13811.801653984647},
#   {'event_0': 641.4833465335877,
#    'event_1': 151.01731488085164,
#    'event_2': -467.00345153257905,
#    'event_3': -637.3026510924491,
#    'event_4': -1496.9211528901978,
#    'event_5': -2051.2311960455627,
#    'event_6': -5091.243496591965,
#    'event_7': -7342.559033316264,
#    'event_8': -9511.21051475445,
#    'event_9': -10035.56922950144},
#   {'event_0': 611.1526105785618,
#    'event_1': -126.25941904823922,
#    'event_2': -405.75583185110816,
#    'event_3': -343.9110194729382,
#    'event_4': -2899.7467298582787,
#    'event_5': -3281.445250845957,
#    'event_6': -3922.264334010327,
#    'event_7': -10503.67205001551,
#    'event_8': -13373.783732737147,
#    'event_9': -12276.460525351245},
#   {'event_0': 632.2672803383172,
#    'event_1': -44.22443630188469,
#    'event_2': -400.93492362755796,
#    'event_3': -1177.0826929447844,
#    'event_4': -3019.6823679806357,
#    'event_5': -1910.7709108688073,
#    'event_6': -4750.789490146585,
#    'event_7': -9749.198989993316,
#    'event_8': -9463.04756542516,
#    'event_9': -11784.884807756878},
#   {'event_0': 625.3610689058079,
#    'event_1': 161.75426257876896,
#    'event_2': -404.3013226766911,
#    'event_3': -499.79836522281323,
#    'event_4': -2035.8030498434553,
#    'event_5': -1374.37462513841,
#    'event_6': -4376.032882249887,
#    'event_7': -6510.809453703913,
#    'event_8': -9714.206369755462,
#    'event_9': -10760.132318131255},
#   {'event_0': 601.8404504195287,
#    'event_1': -77.1951823847813,
#    'event_2': -286.0227922254347,
#    'event_3': -1010.6914914248812,
#    'event_4': -2707.6679448505706,
#    'event_5': -2182.020725941095,
#    'event_6': -4064.2173124298333,
#    'event_7': -10938.81584648072,
#    'event_8': -14367.0491087906,
#    'event_9': -11281.526502273842},
#   {'event_0': 687.2515736977886,
#    'event_1': -89.51442478209967,
#    'event_2': -145.7943925832513,
#    'event_3': -840.9112513784975,
#    'event_4': -1505.729213223995,
#    'event_5': -2300.9856555217834,
#    'event_6': -5683.334769651958,
#    'event_7': -6465.524584602497,
#    'event_8': -9400.828619729193,
#    'event_9': -9210.290623912662},
#   {'event_0': 647.583053769089,
#    'event_1': -110.0827109970133,
#    'event_2': -179.3884548928168,
#    'event_3': -915.0076008719097,
#    'event_4': -1212.5890752274217,
#    'event_5': -2189.4960408448546,
#    'event_6': -4720.43582405631,
#    'event_7': -7509.907443279354,
#    'event_8': -8626.223816909189,
#    'event_9': -11620.469070294395},
#   {'event_0': 586.4577959716479,
#    'event_1': -80.20233304481808,
#    'event_2': -586.7933311643875,
#    'event_3': -1168.293117262873,
#    'event_4': -2005.1692878542929,
#    'event_5': -2622.9213708592215,
#    'event_6': -3569.6064741780447,
#    'event_7': -9847.951071030824,
#    'event_8': -10292.42331029236,
#    'event_9': -10407.250023696994}],
#  'event_7': [{'event_0': 567.4587374565795,
#    'event_1': -44.448535138462496,
#    'event_2': -250.1845536394695,
#    'event_3': -345.7864032830467,
#    'event_4': -864.0366255454818,
#    'event_5': -1121.494662236041,
#    'event_6': -2000.0890704465348,
#    'event_7': -1275.5965915689947,
#    'event_8': -3678.647416826933,
#    'event_9': -3229.6315841846113},
#   {'event_0': 605.692520642218,
#    'event_1': 261.52223619576205,
#    'event_2': -64.93840335235194,
#    'event_3': -389.05472607750283,
#    'event_4': -1287.946885276654,
#    'event_5': -1839.230879201038,
#    'event_6': -5540.080100432468,
#    'event_7': -3751.328341643329,
#    'event_8': -8231.072070504735,
#    'event_9': -8035.928889597493},
#   {'event_0': 618.2909218094794,
#    'event_1': 160.47769833111695,
#    'event_2': -926.5873127534319,
#    'event_3': -886.253508745529,
#    'event_4': -1773.957609241716,
#    'event_5': -2015.625328804877,
#    'event_6': -5394.195632233708,
#    'event_7': -4570.869296917452,
#    'event_8': -9978.06008641801,
#    'event_9': -12696.897937844744},
#   {'event_0': 588.843351949857,
#    'event_1': 54.1324509848447,
#    'event_2': -617.9338249446837,
#    'event_3': -764.0107537567459,
#    'event_4': -2325.082668594801,
#    'event_5': -2962.061806626207,
#    'event_6': -5041.827027228248,
#    'event_7': -4954.594068902683,
#    'event_8': -9556.671672280378,
#    'event_9': -13270.395239882582},
#   {'event_0': 716.7154037795983,
#    'event_1': -1.696937741257095,
#    'event_2': -538.5334701362868,
#    'event_3': -1132.425256363676,
#    'event_4': -1976.993050387525,
#    'event_5': -1944.0508047989972,
#    'event_6': -3735.7527332293394,
#    'event_7': -5635.893112543059,
#    'event_8': -8184.036866986536,
#    'event_9': -9622.220599657592},
#   {'event_0': 653.3781571275605,
#    'event_1': 273.73623379885055,
#    'event_2': -534.6214405570444,
#    'event_3': -759.8924484403115,
#    'event_4': -1398.130305382836,
#    'event_5': -1765.299265403447,
#    'event_6': -7028.582135097873,
#    'event_7': -5376.866937522187,
#    'event_8': -7884.033655932569,
#    'event_9': -9804.41412034623},
#   {'event_0': 705.6294178399513,
#    'event_1': -3.9286953382917726,
#    'event_2': -191.73715746621764,
#    'event_3': -172.33213586131424,
#    'event_4': -1871.720556123989,
#    'event_5': -2354.771896547532,
#    'event_6': -4356.347469319821,
#    'event_7': -6393.932992329436,
#    'event_8': -10128.914252453897,
#    'event_9': -9386.778560285491},
#   {'event_0': 660.6390938546091,
#    'event_1': -84.08368824035162,
#    'event_2': -358.7858877156976,
#    'event_3': -1251.0079710752627,
#    'event_4': -2249.870276763995,
#    'event_5': -1821.6964615548998,
#    'event_6': -6025.808583707632,
#    'event_7': -6244.857806108131,
#    'event_8': -10188.64424054704,
#    'event_9': -11036.45985296705},
#   {'event_0': 618.0362592281631,
#    'event_1': 109.9888672415666,
#    'event_2': -304.58106784369994,
#    'event_3': -438.5171711038103,
#    'event_4': -2110.2676117764377,
#    'event_5': -1962.2145278810517,
#    'event_6': -6335.052281977935,
#    'event_7': -4344.395231937799,
#    'event_8': -10700.72420038889,
#    'event_9': -12447.783312860123},
#   {'event_0': 658.689224363312,
#    'event_1': 19.894491631215047,
#    'event_2': -481.4700894593567,
#    'event_3': -635.6791105232841,
#    'event_4': -2093.2525556168844,
#    'event_5': -1387.3725756948074,
#    'event_6': -6174.994350693668,
#    'event_7': -5801.2692387398165,
#    'event_8': -11554.065605974574,
#    'event_9': -8875.699208176984},
#   {'event_0': 685.9187897609601,
#    'event_1': -102.51323750012813,
#    'event_2': -46.18002983215912,
#    'event_3': -854.2224674712954,
#    'event_4': -1673.9569256249376,
#    'event_5': -2143.0332829382783,
#    'event_6': -8075.183490968437,
#    'event_7': -4977.111302573537,
#    'event_8': -9283.37913787271,
#    'event_9': -9124.584897709643},
#   {'event_0': 679.3533725062694,
#    'event_1': -2.5883397780690895,
#    'event_2': 28.705239008105025,
#    'event_3': -949.0080232194716,
#    'event_4': -1135.726167048056,
#    'event_5': -2594.2833012858705,
#    'event_6': -5475.171189796268,
#    'event_7': -5340.2480572477725,
#    'event_8': -8372.822684540837,
#    'event_9': -11926.211176994904},
#   {'event_0': 633.764261110561,
#    'event_1': 91.72549380405056,
#    'event_2': -311.1847704914925,
#    'event_3': -516.8420151838168,
#    'event_4': -1693.5782288378618,
#    'event_5': -1911.9477345123692,
#    'event_6': -4273.9658331683295,
#    'event_7': -5830.509737420269,
#    'event_8': -7722.464099894045,
#    'event_9': -7756.176025510774}],
#  'event_8': [{'event_0': 609.7319042338473,
#    'event_1': 97.67745642074605,
#    'event_2': -159.91177883908506,
#    'event_3': -166.9407833154433,
#    'event_4': -537.977207852161,
#    'event_5': -716.3473102755435,
#    'event_6': -1478.20547406129,
#    'event_7': -1628.5605927554798,
#    'event_8': -1909.2689348096787,
#    'event_9': -2415.894050972042},
#   {'event_0': 671.5682050249396,
#    'event_1': 337.2212000969515,
#    'event_2': 47.6309015869781,
#    'event_3': -262.37215397551927,
#    'event_4': -1210.201847872396,
#    'event_5': -1521.7692690321153,
#    'event_6': -4728.277041868274,
#    'event_7': -4536.79407517741,
#    'event_8': -5611.708728359752,
#    'event_9': -7033.405764672386},
#   {'event_0': 684.0472299971292,
#    'event_1': 231.69891164684543,
#    'event_2': -643.2743425694666,
#    'event_3': -550.3566999260208,
#    'event_4': -1442.5567423953164,
#    'event_5': -1426.7516851550326,
#    'event_6': -4596.135437332112,
#    'event_7': -5993.982442420298,
#    'event_8': -6325.091872327907,
#    'event_9': -10120.555378671083},
#   {'event_0': 643.3416199371259,
#    'event_1': 240.53802229288053,
#    'event_2': -490.93633063509077,
#    'event_3': -565.8257407841719,
#    'event_4': -1867.1015486379306,
#    'event_5': -2950.428593202526,
#    'event_6': -4828.021737690672,
#    'event_7': -7164.607258493816,
#    'event_8': -5554.888890684433,
#    'event_9': -11312.38185176699},
#   {'event_0': 709.6054030903994,
#    'event_1': -1.5988030020646171,
#    'event_2': -484.11294903342184,
#    'event_3': -954.7411532664861,
#    'event_4': -2097.803581755931,
#    'event_5': -2270.6880785223693,
#    'event_6': -3362.0190838190515,
#    'event_7': -7799.504774098636,
#    'event_8': -6073.112082694146,
#    'event_9': -10595.028938984306},
#   {'event_0': 659.8565281344837,
#    'event_1': 243.64221968362958,
#    'event_2': -530.4547186223227,
#    'event_3': -994.7422982513749,
#    'event_4': -1312.606155639441,
#    'event_5': -2580.095923916874,
#    'event_6': -7833.985191004795,
#    'event_7': -7284.091702258493,
#    'event_8': -6046.519599211185,
#    'event_9': -9048.70887651218},
#   {'event_0': 701.4193321087853,
#    'event_1': 48.746688372194015,
#    'event_2': -54.00599036629743,
#    'event_3': -224.26279444941693,
#    'event_4': -1874.3733845107508,
#    'event_5': -2433.382769882523,
#    'event_6': -4582.30216234062,
#    'event_7': -7771.454494806724,
#    'event_8': -7777.848012728953,
#    'event_9': -9714.811185488863},
#   {'event_0': 712.5442136429114,
#    'event_1': 79.1286551608188,
#    'event_2': -236.43299142832518,
#    'event_3': -942.630364250323,
#    'event_4': -2093.972587785696,
#    'event_5': -1492.3274965861963,
#    'event_6': -5584.03676581195,
#    'event_7': -8311.077534132428,
#    'event_8': -6596.957067479613,
#    'event_9': -9621.36066972427},
#   {'event_0': 666.032153202167,
#    'event_1': 237.41469986482556,
#    'event_2': -335.1281934272586,
#    'event_3': -432.50954305093114,
#    'event_4': -1640.5653988595398,
#    'event_5': -1392.8795486891986,
#    'event_6': -5582.712764289435,
#    'event_7': -5993.079288212334,
#    'event_8': -6578.999058680898,
#    'event_9': -10360.383642602153},
#   {'event_0': 708.6689369822425,
#    'event_1': 222.6124477136167,
#    'event_2': -53.83847200807931,
#    'event_3': -474.6090172657503,
#    'event_4': -1578.064955663806,
#    'event_5': -1241.141990526455,
#    'event_6': -4335.669463932358,
#    'event_7': -6738.5248763917925,
#    'event_8': -8614.371638660983,
#    'event_9': -8637.274903425081},
#   {'event_0': 712.3177988447854,
#    'event_1': 119.4403614835163,
#    'event_2': 11.219474712381842,
#    'event_3': -526.9501605496944,
#    'event_4': -1324.612816237402,
#    'event_5': -2181.845231644438,
#    'event_6': -6852.827198799514,
#    'event_7': -6439.592101555172,
#    'event_8': -6528.836032537024,
#    'event_9': -9232.934221733274},
#   {'event_0': 660.6318574439822,
#    'event_1': -31.290833580838125,
#    'event_2': -136.7934470289335,
#    'event_3': -883.5932896831843,
#    'event_4': -1244.279957543521,
#    'event_5': -2632.3801593329963,
#    'event_6': -6374.939133276151,
#    'event_7': -7775.221101405427,
#    'event_8': -6353.912390761487,
#    'event_9': -11505.319712005574},
#   {'event_0': 679.0390142806244,
#    'event_1': 195.92997483381137,
#    'event_2': -206.0205667350549,
#    'event_3': -547.6731223759689,
#    'event_4': -1344.3147293976913,
#    'event_5': -1707.991796678758,
#    'event_6': -3977.841765843039,
#    'event_7': -7485.8929388541865,
#    'event_8': -6096.6084003636215,
#    'event_9': -7725.4918397317715}],
#  'event_9': [{'event_0': 614.7901085730925,
#    'event_1': 31.659357903666987,
#    'event_2': -77.88638193541622,
#    'event_3': -124.65741438502715,
#    'event_4': -498.1505296612037,
#    'event_5': -579.102283647367,
#    'event_6': -1651.2882885845313,
#    'event_7': -1598.2540236479967,
#    'event_8': -2718.80143141594,
#    'event_9': -1758.1751966046224},
#   {'event_0': 673.3138761745663,
#    'event_1': 268.74894810473825,
#    'event_2': -120.80081211300346,
#    'event_3': -369.7469724820355,
#    'event_4': -1414.8553131884478,
#    'event_5': -2136.090855498326,
#    'event_6': -5161.772062897368,
#    'event_7': -4942.848232449509,
#    'event_8': -7377.31806357076,
#    'event_9': -5514.235633755606},
#   {'event_0': 680.8869418697406,
#    'event_1': 313.7337934939567,
#    'event_2': -620.3201177802298,
#    'event_3': -579.1794503079311,
#    'event_4': -1108.4064000798023,
#    'event_5': -1531.1748586739768,
#    'event_6': -4303.729553923519,
#    'event_7': -5918.879005852648,
#    'event_8': -7908.284017207427,
#    'event_9': -7799.198136768473},
#   {'event_0': 670.4387110111909,
#    'event_1': 247.37282780524623,
#    'event_2': -276.2557792162957,
#    'event_3': -236.99174727041884,
#    'event_4': -1508.5811602975436,
#    'event_5': -2500.250585160543,
#    'event_6': -4012.8496046266528,
#    'event_7': -6509.726950477741,
#    'event_8': -7458.84814375029,
#    'event_9': -7834.358372325345},
#   {'event_0': 732.5118882387017,
#    'event_1': 88.3652415738644,
#    'event_2': -483.4419846221845,
#    'event_3': -1111.9203253618375,
#    'event_4': -2056.893797433908,
#    'event_5': -1819.5031804456485,
#    'event_6': -3515.337564388285,
#    'event_7': -7272.994633597026,
#    'event_8': -8305.930121163994,
#    'event_9': -7425.493405559871},
#   {'event_0': 653.1321636209963,
#    'event_1': 175.94254993704047,
#    'event_2': -634.886665494423,
#    'event_3': -720.6361230464744,
#    'event_4': -1543.95183839823,
#    'event_5': -2472.5763273864914,
#    'event_6': -6932.419584980161,
#    'event_7': -7434.2345528339765,
#    'event_8': -8005.315028163077,
#    'event_9': -6841.137008091286},
#   {'event_0': 723.9640027143822,
#    'event_1': 125.9948062834151,
#    'event_2': -47.03832185800308,
#    'event_3': -187.9261805692057,
#    'event_4': -1835.7241145957482,
#    'event_5': -2846.2088329585513,
#    'event_6': -4387.144885926736,
#    'event_7': -8199.638491853328,
#    'event_8': -10108.491084832216,
#    'event_9': -7514.928604987038},
#   {'event_0': 681.8646488540127,
#    'event_1': 158.30217356444032,
#    'event_2': -333.91245949612505,
#    'event_3': -1583.7419725903692,
#    'event_4': -2317.6277395934258,
#    'event_5': -1808.3307542575628,
#    'event_6': -7053.99132465753,
#    'event_7': -8872.492931095634,
#    'event_8': -8911.313573581961,
#    'event_9': -7323.907200570494},
#   {'event_0': 668.5059737658564,
#    'event_1': 131.50223713221516,
#    'event_2': -321.4081743695916,
#    'event_3': -201.5424118642731,
#    'event_4': -1609.5676920733113,
#    'event_5': -1057.9648062438164,
#    'event_6': -4925.285111825297,
#    'event_7': -6093.038535230741,
#    'event_8': -8761.384407203654,
#    'event_9': -7307.452931591845},
#   {'event_0': 634.2235539153493,
#    'event_1': 69.72688639883607,
#    'event_2': -355.9979163442697,
#    'event_3': -667.1928837418246,
#    'event_4': -2084.071899223828,
#    'event_5': -1526.254577561626,
#    'event_6': -5552.161886172659,
#    'event_7': -8706.590056932502,
#    'event_8': -13666.156263726903,
#    'event_9': -6966.191715405682},
#   {'event_0': 707.034276927237,
#    'event_1': -67.92314819776479,
#    'event_2': 56.75405997929609,
#    'event_3': -594.564065370034,
#    'event_4': -1495.3542653281543,
#    'event_5': -2232.438933905654,
#    'event_6': -7075.880118580316,
#    'event_7': -5963.10541973965,
#    'event_8': -9116.75256639015,
#    'event_9': -6743.437262757869},
#   {'event_0': 713.9201395029784,
#    'event_1': 117.80766404519869,
#    'event_2': -22.016627369277366,
#    'event_3': -550.182783372133,
#    'event_4': -973.5032591231541,
#    'event_5': -2442.7820965624223,
#    'event_6': -5248.336855520412,
#    'event_7': -6463.452950925652,
#    'event_8': -6995.233655514054,
#    'event_9': -8616.699366932464},
#   {'event_0': 621.628611406942,
#    'event_1': 61.416426130480055,
#    'event_2': -485.1671069688371,
#    'event_3': -499.70047497686755,
#    'event_4': -1735.6853792485917,
#    'event_5': -2180.7792125912165,
#    'event_6': -4750.86419233187,
#    'event_7': -8851.55874607757,
#    'event_8': -9601.499950178653,
#    'event_9': -6111.963230042945}]}

# %% [markdown]
# Try extracting transference of the last epoch

# %%
# revised_integrals = {}
# for  key, value in revised_integrals0.items():
#     revised_integrals[key] = value[-1]
    
# revised_integrals
# Out:
# {'event_0': {'event_0': 0.8421101734003056,
#   'event_1': -2007.5820827734435,
#   'event_2': -3368.492014958791,
#   'event_3': -3815.2738318856304,
#   'event_4': -7837.807517865199,
#   'event_5': -8992.85540723425,
#   'event_6': -16415.717913009365,
#   'event_7': -31959.375345700686,
#   'event_8': -31820.181235566226,
#   'event_9': -32190.331714359792},
#  'event_1': {'event_0': 233.22727653923934,
#   'event_1': -408.4717166580239,
#   'event_2': -1846.8135468227656,
#   'event_3': -2408.053610243509,
#   'event_4': -4238.634204213701,
#   'event_5': -5004.012866533335,
#   'event_6': -11736.720106376439,
#   'event_7': -19574.218996603653,
#   'event_8': -18142.42605214356,
#   'event_9': -16961.786605329336},
#  'event_2': {'event_0': 457.8188268906802,
#   'event_1': -315.1845834887247,
#   'event_2': -541.6756873243438,
#   'event_3': -1861.1533450329396,
#   'event_4': -3073.8888254190674,
#   'event_5': -3605.534272306547,
#   'event_6': -7309.485717232773,
# ...

# %%
revised_integrals = {'event_0': {'event_0': 0.1676502441752118,
  'event_1': 268.0672424506015,
  'event_2': 1090.223630635366,
  'event_3': 1034.0149390852748,
  'event_4': 1316.5458662231445,
  'event_5': 1594.0879625551152,
  'event_6': 1968.869918319575,
  'event_7': 2069.0075770614967,
  'event_8': 2201.4261463507432,
  'event_9': 2126.6628538331415},
 'event_1': {'event_0': -12173.91815065931,
  'event_1': -0.35045399324567583,
  'event_2': -2867.081470238401,
  'event_3': -2906.3219327063857,
  'event_4': -1719.91850568843,
  'event_5': -647.2508086118322,
  'event_6': 452.3017529576938,
  'event_7': 597.2234165864429,
  'event_8': 961.389024364119,
  'event_9': 858.4555422250678},
 'event_2': {'event_0': -18447.93857737546,
  'event_1': -8618.020076084207,
  'event_2': 0.8274456191980015,
  'event_3': -5509.321866241222,
  'event_4': -4224.451898412577,
  'event_5': -2699.9396189048866,
  'event_6': -987.9787825449246,
  'event_7': -586.8622976176496,
  'event_8': 174.2278201171734,
  'event_9': -76.72034309473955},
 'event_3': {'event_0': -22960.819741003448,
  'event_1': -10799.47231689299,
  'event_2': -7010.200794908929,
  'event_3': -0.3588745193085398,
  'event_4': -5259.104134547415,
  'event_5': -3312.8415827790277,
  'event_6': -1593.3780642417782,
  'event_7': -1307.040893290808,
  'event_8': -398.2314856007813,
  'event_9': -1028.359664249178},
 'event_4': {'event_0': -34510.10131629329,
  'event_1': -16701.00141306006,
  'event_2': -11490.162589065378,
  'event_3': -11388.788892080773,
  'event_4': -0.06831299161567198,
  'event_5': -6162.25890501126,
  'event_6': -3398.555437990844,
  'event_7': -3301.77378883418,
  'event_8': -1896.772708362531,
  'event_9': -2325.7223800610836},
 'event_5': {'event_0': -41955.59549327208,
  'event_1': -20887.755951907864,
  'event_2': -13860.279247990626,
  'event_3': -13924.71446747863,
  'event_4': -11506.637416453841,
  'event_5': -2.288036602894528,
  'event_6': -4730.762262531876,
  'event_7': -4313.7430754286725,
  'event_8': -2694.596528937419,
  'event_9': -3175.237920473254},
 'event_6': {'event_0': -80676.313191333,
  'event_1': -40631.470083921144,
  'event_2': -28989.78942877645,
  'event_3': -28894.06749892453,
  'event_4': -23191.345501082404,
  'event_5': -17143.797239311665,
  'event_6': 0.10124709895748492,
  'event_7': -10280.697656513628,
  'event_8': -7402.7233923493895,
  'event_9': -8508.469689817883},
 'event_7': {'event_0': -88569.83102448241,
  'event_1': -46237.97058718399,
  'event_2': -32203.105591639447,
  'event_3': -32880.67243309695,
  'event_4': -26640.724959318013,
  'event_5': -19401.175602484993,
  'event_6': -12761.23306630453,
  'event_7': 0.15111570671968289,
  'event_8': -8522.962652509324,
  'event_9': -9917.494648251542},
 'event_8': {'event_0': -110428.72966865606,
  'event_1': -57412.19734008496,
  'event_2': -39916.37220858559,
  'event_3': -40635.676545142494,
  'event_4': -33775.48484763561,
  'event_5': -24825.318743545155,
  'event_6': -16368.93564884456,
  'event_7': -14941.440147584504,
  'event_8': -0.10358445587283223,
  'event_9': -12590.927466973375},
 'event_9': {'event_0': -117902.96050378475,
  'event_1': -61541.01547247431,
  'event_2': -42145.55501569586,
  'event_3': -44136.80068035897,
  'event_4': -35500.19819810407,
  'event_5': -26486.30456384062,
  'event_6': -17310.227864524022,
  'event_7': -16519.11830338061,
  'event_8': -12097.472459036057,
  'event_9': 0.00752159233847891}}

# %%
# def rev_transference(batch_transference):
    # rev_transference = {source: {} for source in batch_transference}
    # for grad_task in batch_transference:
        # for source in batch_transference[grad_task]:
            # if 'Loss' in source:
                # continue
        	# rev_transference[source][grad_task] = batch_transference[grad_task][source]
    # return rev_transference

# revised_integrals = rev_transference(revised_integrals)
# revised_integrals

# %%
# def convert_to_negative(d):
#     for key, value in d.items():
#         if isinstance(value, dict):
#             # Recursively call the function for nested dictionaries
#             # print(key, value)
#             convert_to_negative(value)
#         else:
#             # Convert the value to its negative equivalent
#             # print('d[key]', d[key])
#             d[key] = -abs(value)

# convert_to_negative(revised_integrals)
# revised_integrals

# %% [markdown]
# ### Network Selection

# %%
import math 
import numpy as np

def gen_task_combinations(tasks, rtn, index, path, path_dict):
  if index >= len(tasks):
    return 

  for i in range(index, len(tasks)):
    cur_task = tasks[i]
    new_path = path
    new_dict = {k:v for k,v in path_dict.items()}
    
    # Building from a tree with two or more tasks...
    if new_path:
      print('#####')
      print('new_path', new_path)
      print('cur_task', cur_task)
      
      new_dict[cur_task] = 0.
      for prev_task in path_dict:
        print('prev_task', prev_task)
        print('path_dict', path_dict)
        new_dict[prev_task] += revised_integrals[prev_task][cur_task]
        new_dict[cur_task] += revised_integrals[cur_task][prev_task]
        print('new_dict', new_dict)
      new_path = '{}|{}'.format(new_path, cur_task)
      rtn[new_path] = new_dict
    else: # First element in a new-formed tree
      new_dict[cur_task] = 0.
      new_path = cur_task

    gen_task_combinations(tasks, rtn, i+1, new_path, new_dict)


    if '|' not in new_path:
      new_dict[cur_task] = -1e6 
      rtn[new_path] = new_dict
      
  return new_dict, rtn

# %%
# Experiment
# rtn = {}
# tasks = list(revised_integrals.keys())
# num_tasks = len(tasks)
# task_combinations = gen_task_combinations(tasks=tasks, rtn=rtn, index=0, path='', path_dict={})
# Out:
# #####
# new_path event_0
# cur_task event_1
# prev_task event_0
# path_dict {'event_0': 0.0}
# new_dict {'event_0': -10905.417316031504, 'event_1': 78.42060319977212}
# #####
# new_path event_0|event_1
# cur_task event_2
# prev_task event_0
# path_dict {'event_0': -10905.417316031504, 'event_1': 78.42060319977212}
# new_dict {'event_0': -26787.39149902254, 'event_1': 78.42060319977212, 'event_2': 518.5048595820458}
# prev_task event_1
# path_dict {'event_0': -10905.417316031504, 'event_1': 78.42060319977212}
# new_dict {'event_0': -26787.39149902254, 'event_1': -6754.045304437841, 'event_2': -2439.9899945975644}
# #####
# new_path event_0|event_1|event_2
# cur_task event_3
# prev_task event_0
# path_dict {'event_0': -26787.39149902254, 'event_1': -6754.045304437841, 'event_2': -2439.9899945975644}
# new_dict {'event_0': -47927.84286948314, 'event_1': -6754.045304437841, 'event_2': -2439.9899945975644, 'event_3': 660.9510593043221}
# prev_task event_1
# ...

# %%
rtn = {}
tasks = list(revised_integrals.keys())
num_tasks = len(tasks)
task_combinations = gen_task_combinations(tasks=tasks, rtn=rtn, index=0, path='', path_dict={})

# Normalize by the number of times the accuracy of any given element has been summed. 
# i.e. (a,b,c) => [acc(a|b) + acc(a|c)]/2 + [acc(b|a) + acc(b|c)]/2 + [acc(c|a) + acc(c|b)]/2
for group in rtn:
  if '|' in group:
    for task in rtn[group]:
      rtn[group][task] /= (len(group.split('|')) - 1)

print(rtn)
assert(len(rtn.keys()) == 2**len(revised_integrals.keys()) - 1)
rtn_tup = [(key,val) for key,val in rtn.items()]
# Out:
# #####
# new_path event_0
# cur_task event_1
# prev_task event_0
# path_dict {'event_0': 0.0}
# new_dict {'event_0': 268.0672424506015, 'event_1': -12173.91815065931}
# #####
# new_path event_0|event_1
# cur_task event_2
# prev_task event_0
# path_dict {'event_0': 268.0672424506015, 'event_1': -12173.91815065931}
# new_dict {'event_0': 1358.2908730859674, 'event_1': -12173.91815065931, 'event_2': -18447.93857737546}
# prev_task event_1
# path_dict {'event_0': 268.0672424506015, 'event_1': -12173.91815065931}
# new_dict {'event_0': 1358.2908730859674, 'event_1': -15040.999620897712, 'event_2': -27065.958653459667}
# #####
# new_path event_0|event_1|event_2
# cur_task event_3
# prev_task event_0
# path_dict {'event_0': 1358.2908730859674, 'event_1': -15040.999620897712, 'event_2': -27065.958653459667}
# new_dict {'event_0': 2392.305812171242, 'event_1': -15040.999620897712, 'event_2': -27065.958653459667, 'event_3': -22960.819741003448}
# prev_task event_1
# ...

# %%
# print(task_combinations[0])
print(task_combinations[1])
# Out:
# {'event_0|event_1': {'event_0': -10905.417316031504, 'event_1': 78.42060319977212}, 'event_0|event_1|event_2': {'event_0': -13393.69574951127, 'event_1': -3377.0226522189205, 'event_2': -1219.9949972987822}, 'event_0|event_1|event_2|event_3': {'event_0': -15975.947623161046, 'event_1': -5378.530220562535, 'event_2': -3274.052609812685, 'event_3': -2048.7013087832734}, 'event_0|event_1|event_2|event_3|event_4': {'event_0': -20100.339441110544, 'event_1': -7866.028882618115, 'event_2': -5487.196162773282, 'event_3': -3867.6157671507503, 'event_4': -1924.7414105297596}, 'event_0|event_1|event_2|event_3|event_4|event_5': {'event_0': -23554.700374674165, 'event_1': -9786.958408181075, 'event_2': -7150.580988327102, 'event_3': -5508.19521781587, 'event_4': -3211.3797677433517, 'event_5': -2055.3309770668734}, 'event_0|event_1|event_2|event_3|event_4|event_5|event_6': {'event_0': -30656.963473693148, 'event_1': -13379.217997807653, 'event_2': -10211.889805651961, 'event_3': -8056.3048362243
# ...

# %%
def select_groups(index, cur_group, best_group, best_val, splits):
  # Check if this group covers all tasks.
  task_set = set()
  for group in cur_group:
    for task in group.split('|'): task_set.add(task)
  if len(task_set) == num_tasks:
    best_tasks = {task:-1e6 for task in task_set}
    
    # Compute the per-task best scores for each task and average them together.
    for group in cur_group:
      for task in cur_group[group]:
        best_tasks[task] = max(best_tasks[task], cur_group[group][task])
    group_avg = np.mean(list(best_tasks.values()))
    
    # Compare with the best grouping seen thus far.
    if group_avg > best_val[0]:
      print(cur_group)
      best_val[0] = group_avg
      best_group.clear()
      for entry in cur_group:
        best_group[entry] = cur_group[entry]
  
  # Base case.
  if len(cur_group.keys()) == splits:
    return

  # Back to combinatorics 
  for i in range(index, len(rtn_tup)):
    selected_group, selected_dict = rtn_tup[i]

    new_group = {k:v for k,v in cur_group.items()}
    new_group[selected_group] = selected_dict

    if len(new_group.keys()) <= splits:
      select_groups(i + 1, new_group, best_group, best_val, splits)

selected_group = {}
selected_val = [-100000000]
select_groups(index=0, cur_group={}, best_group=selected_group, best_val=selected_val, splits=3)
print(selected_group)
print(selected_val)
# Out:
# {'event_0|event_1': {'event_0': 268.0672424506015, 'event_1': -12173.91815065931}, 'event_0|event_1|event_2': {'event_0': 679.1454365429837, 'event_1': -7520.499810448856, 'event_2': -13532.979326729834}, 'event_0|event_1|event_2|event_3|event_4|event_5|event_6|event_7|event_8|event_9': {'event_0': 1518.7673485016066, 'event_1': -1938.3467924190045, 'event_2': -4553.000626684277, 'event_3': -5963.272075279373, 'event_4': -10130.570825639932, 'event_5': -13005.480262719362, 'event_6': -27302.0748535589, 'event_7': -30792.796729474576, 'event_8': -38988.34251300581, 'event_9': -41515.51700679992}}
# ...

# %%
selected_group
# Out:
# {'event_0|event_1|event_5|event_6|event_7|event_8|event_9': {'event_0': 1704.6869500951118,
#   'event_1': -1658.6332038563032,
#   'event_5': -12959.615205425194,
#   'event_6': -27440.578542207786,
#   'event_7': -30901.777930202796,
#   'event_8': -39427.9248359481,
#   'event_9': -41976.18319450673},
#  'event_2|event_3|event_4|event_5|event_6|event_7|event_8|event_9': {'event_2': -1987.292426671261,
#   'event_3': -2844.165231373988,
#   'event_4': -5709.147814486577,
#   'event_5': -7743.71013132776,
#   'event_6': -17772.984343825134,
#   'event_7': -20332.4812790864,
#   'event_8': -26150.593658330185,
#   'event_9': -27742.239583562892},
#  'event_6|event_7|event_8|event_9': {'event_6': -8730.630246226967,
#   'event_7': -10400.563455688467,
#   'event_8': -14633.76775446748,
#   'event_9': -15308.939542313563}}

# %%
selected_val
# Out:
# [-6731.216285631725]

# %% [markdown]
# ### Old

# %%
selected_group
# Out:
# {'event_0|event_1|event_3|event_4|event_7|event_9': {'event_0': -4746146.085055774,
#   'event_1': -2254989.8136687996,
#   'event_3': -1399907.310203412,
#   'event_4': -1468941.0283792652,
#   'event_7': -636706.5944446154,
#   'event_9': -299407.3956154651},
#  'event_0|event_1|event_5|event_6': {'event_0': -4580122.874015748,
#   'event_1': -2020328.233062664,
#   'event_5': -673801.1757197342,
#   'event_6': -558043.2984231464},
#  'event_0|event_2|event_8': {'event_0': -5019605.161581364,
#   'event_2': -1864655.6497088254,
#   'event_8': -323991.47668553144}}

# %%
# With weights
epoch_transference = {'event_0': {'event_0': -5048738.775510204, 'event_1': -2169753.265306122, 'event_2': -23647146.122448977, 'event_3': -12391873.469387755, 'event_4': -15666401.63265306, 'event_5': -2594073.87755102, 'event_6': -18460075.102040816, 'event_7': -6381208.979591836, 'event_8': -5463433.0612244895, 'event_9': -7583877.551020408}, 'event_1': {'event_0': -5004883.265306122, 'event_1': -2150895.5102040814, 'event_2': -23441800.81632653, 'event_3': -12284257.142857142, 'event_4': -15530352.653061224, 'event_5': -2571531.632653061, 'event_6': -18299768.163265307, 'event_7': -6325783.265306122, 'event_8': -5415976.734693877, 'event_9': -7518008.979591836}, 'event_2': {'event_0': -5336556.326530612, 'event_1': -2293512.244897959, 'event_2': -24994788.57142857, 'event_3': -13098136.326530611, 'event_4': -16559263.673469387, 'event_5': -2742012.653061224, 'event_6': -19512133.87755102, 'event_7': -6744956.734693877, 'event_8': -5774882.040816326, 'event_9': -8016159.183673468}, 'event_3': {'event_0': -5174128.979591836, 'event_1': -2223670.0, 'event_2': -24234257.95918367, 'event_3': -12699562.44897959, 'event_4': -16055382.857142856, 'event_5': -2658524.489795918, 'event_6': -18918411.428571425, 'event_7': -6539678.775510204, 'event_8': -5599117.959183673, 'event_9': -7772204.081632652}, 'event_4': {'event_0': -5186940.0, 'event_1': -2229178.5714285714, 'event_2': -24294241.63265306, 'event_3': -12731000.0, 'event_4': -16095126.530612243, 'event_5': -2665109.387755102, 'event_6': -18965240.81632653, 'event_7': -6555869.795918367, 'event_8': -5612981.224489796, 'event_9': -7791445.714285714}, 'event_5': {'event_0': -5024267.75510204, 'event_1': -2159230.8163265307, 'event_2': -23532563.265306123, 'event_3': -12331823.673469387, 'event_4': -15590486.530612243, 'event_5': -2581495.3061224488, 'event_6': -18370623.673469387, 'event_7': -6350282.040816326, 'event_8': -5436952.244897959, 'event_9': -7547123.265306122}, 'event_6': {'event_0': -5232421.224489796, 'event_1': -2248735.102040816, 'event_2': -24507198.36734694, 'event_3': -12842604.081632651, 'event_4': -16236217.142857142, 'event_5': -2688486.93877551, 'event_6': -19131488.979591835, 'event_7': -6613349.387755102, 'event_8': -5662196.734693877, 'event_9': -7859755.918367347}, 'event_7': {'event_0': -5048735.918367347, 'event_1': -2169752.040816326, 'event_2': -23647131.428571425, 'event_3': -12391865.306122448, 'event_4': -15666391.836734693, 'event_5': -2594072.040816326, 'event_6': -18460062.040816326, 'event_7': -6381205.714285714, 'event_8': -5463430.204081632, 'event_9': -7583872.653061224}, 'event_8': {'event_0': -5018193.469387755, 'event_1': -2156618.9795918367, 'event_2': -23504124.08163265, 'event_3': -12316919.18367347, 'event_4': -15571644.081632651, 'event_5': -2578373.469387755, 'event_6': -18348421.224489793, 'event_7': -6342605.714285714, 'event_8': -5430380.0, 'event_9': -7537999.999999999}, 'event_9': {'event_0': -5061598.775510204, 'event_1': -2175282.653061224, 'event_2': -23707358.36734694, 'event_3': -12423429.387755102, 'event_4': -15706293.87755102, 'event_5': -2600683.6734693875, 'event_6': -18507080.81632653, 'event_7': -6397461.63265306, 'event_8': -5477348.571428571, 'event_9': -7603191.8367346935}}

epoch_transference
# Out:
# {'event_0': {'event_0': -5048738.775510204,
#   'event_1': -2169753.265306122,
#   'event_2': -23647146.122448977,
#   'event_3': -12391873.469387755,
#   'event_4': -15666401.63265306,
#   'event_5': -2594073.87755102,
#   'event_6': -18460075.102040816,
#   'event_7': -6381208.979591836,
#   'event_8': -5463433.0612244895,
#   'event_9': -7583877.551020408},
#  'event_1': {'event_0': -5004883.265306122,
#   'event_1': -2150895.5102040814,
#   'event_2': -23441800.81632653,
#   'event_3': -12284257.142857142,
#   'event_4': -15530352.653061224,
#   'event_5': -2571531.632653061,
#   'event_6': -18299768.163265307,
#   'event_7': -6325783.265306122,
#   'event_8': -5415976.734693877,
#   'event_9': -7518008.979591836},
#  'event_2': {'event_0': -5336556.326530612,
#   'event_1': -2293512.244897959,
#   'event_2': -24994788.57142857,
#   'event_3': -13098136.326530611,
#   'event_4': -16559263.673469387,
#   'event_5': -2742012.653061224,
#   'event_6': -19512133.87755102,
# ...

# %%
# Without weights

epoch_transference2  = {'event_0': {'event_0': 0.105463728612783, 'event_1': -6.718295350366708, 'event_2': 95.3954081632653, 'event_3': 28.39176100127551, 'event_4': 86.26738256337691, 'event_5': -19.628174450932715, 'event_6': 91.97009028220663, 'event_7': 3.839998829121492, 'event_8': 2.746557702823561, 'event_9': 27.985839843749996}, 'event_1': {'event_0': 6.980555008868781, 'event_1': 0.1796654292515346, 'event_2': 101.94948780293366, 'event_3': 35.171483876753825, 'event_4': 92.85223513233417, 'event_5': -12.68654492436623, 'event_6': 98.53572300502232, 'event_7': 10.70243991151148, 'event_8': 9.61276930205676, 'event_9': 34.76702320332429}, 'event_2': {'event_0': -99.82099260602678, 'event_1': -106.97890923947703, 'event_2': 0.13502276673608896, 'event_3': -70.14956104512117, 'event_4': -9.439916026835538, 'event_5': -120.52082918128188, 'event_6': -3.458042534030213, 'event_7': -95.9036317163584, 'event_8': -97.05046984614158, 'event_9': -70.57530617227359}, 'event_3': {'event_0': -28.579574896364793, 'event_1': -35.49906827965561, 'event_2': 68.05001395089285, 'event_3': 0.1044905915552256, 'event_4': 58.79365882095025, 'event_5': -48.59043666294642, 'event_6': 64.57652189293685, 'event_7': -24.79236992038026, 'event_8': -25.901258818957267, 'event_9': -0.30702474165935906}, 'event_4': {'event_0': -89.59040427694515, 'event_1': -96.71401043327486, 'event_2': 9.88804564184072, 'event_3': -60.06080471739477, 'event_4': 0.3587226478420958, 'event_5': -110.19122688137755, 'event_6': 6.312132076341278, 'event_7': -85.6915283203125, 'event_8': -86.8330227598852, 'event_9': -60.48435756138392}, 'event_5': {'event_0': 19.601169508330674, 'event_1': 12.842611196089763, 'event_2': 113.98086236447703, 'event_3': 47.61729960538903, 'event_4': 104.94006098533163, 'event_5': 0.056077022941745054, 'event_6': 110.58826680086096, 'event_7': 23.300063464106344, 'event_8': 22.217083366549744, 'event_9': 47.21527099609375}, 'event_6': {'event_0': -96.03597835618622, 'event_1': -103.18123330875318, 'event_2': 3.7434149761589204, 'event_3': -66.41685018734056, 'event_4': -5.814737203169842, 'event_5': -116.69908173230229, 'event_6': 0.15667506626674105, 'event_7': -92.12542475486288, 'event_8': -93.2703197245695, 'event_9': -66.84186662946428}, 'event_7': {'event_0': -3.7044894938566246, 'event_1': -10.541020607461734, 'event_2': 91.7635423309949, 'event_3': 24.63472171705596, 'event_4': 82.61836460658482, 'event_5': -23.47474234444754, 'event_6': 88.33177216198979, 'event_7': 0.037100850319375794, 'event_8': -1.0582865500936702, 'event_9': 24.22807187450175}, 'event_8': {'event_0': -2.523344390246333, 'event_1': -9.35598256636639, 'event_2': 92.88933578802614, 'event_3': 25.7993238799426, 'event_4': 83.74951420998086, 'event_5': -22.282406553930166, 'event_6': 89.4596395687181, 'event_7': 1.2159347534179688, 'event_8': 0.12115556366589604, 'event_9': 25.392916932397956}, 'event_9': {'event_0': -28.02902221679687, 'event_1': -34.94681222098214, 'event_2': 68.57477927694515, 'event_3': 0.6472577854078643, 'event_4': 59.32085309709821, 'event_5': -48.03453095105229, 'event_6': 65.10214046556122, 'event_7': -24.24303327287946, 'event_8': -25.35143638143734, 'event_9': 0.2358640943254743}}

epoch_transference2
# Out:
# {'event_0': {'event_0': 0.105463728612783,
#   'event_1': -6.718295350366708,
#   'event_2': 95.3954081632653,
#   'event_3': 28.39176100127551,
#   'event_4': 86.26738256337691,
#   'event_5': -19.628174450932715,
#   'event_6': 91.97009028220663,
#   'event_7': 3.839998829121492,
#   'event_8': 2.746557702823561,
#   'event_9': 27.985839843749996},
#  'event_1': {'event_0': 6.980555008868781,
#   'event_1': 0.1796654292515346,
#   'event_2': 101.94948780293366,
#   'event_3': 35.171483876753825,
#   'event_4': 92.85223513233417,
#   'event_5': -12.68654492436623,
#   'event_6': 98.53572300502232,
#   'event_7': 10.70243991151148,
#   'event_8': 9.61276930205676,
#   'event_9': 34.76702320332429},
#  'event_2': {'event_0': -99.82099260602678,
#   'event_1': -106.97890923947703,
#   'event_2': 0.13502276673608896,
#   'event_3': -70.14956104512117,
#   'event_4': -9.439916026835538,
#   'event_5': -120.52082918128188,
#   'event_6': -3.458042534030213,
# ...

# %%
import json

print(json.dumps(epoch_transference2, indent = 1))
# Out:
# {
#  "event_0": {
#   "event_0": 0.105463728612783,
#   "event_1": -6.718295350366708,
#   "event_2": 95.3954081632653,
#   "event_3": 28.39176100127551,
#   "event_4": 86.26738256337691,
#   "event_5": -19.628174450932715,
#   "event_6": 91.97009028220663,
#   "event_7": 3.839998829121492,
#   "event_8": 2.746557702823561,
#   "event_9": 27.985839843749996
#  },
#  "event_1": {
#   "event_0": 6.980555008868781,
#   "event_1": 0.1796654292515346,
#   "event_2": 101.94948780293366,
#   "event_3": 35.171483876753825,
#   "event_4": 92.85223513233417,
#   "event_5": -12.68654492436623,
#   "event_6": 98.53572300502232,
#   "event_7": 10.70243991151148,
#   "event_8": 9.61276930205676,
#   "event_9": 34.76702320332429
#  },
#  "event_2": {
#   "event_0": -99.82099260602678,
#   "event_1": -106.97890923947703,
#   "event_2": 0.13502276673608896,
#   "event_3": -70.14956104512117,
#   "event_4": -9.439916026835538,
#   "event_5": -120.52082918128188,
#   "event_6": -3.458042534030213,
# ...

# %%
batch_transference = {'event_0': {'event_0': 0.38802624, 'event_1': 88.45151, 'event_2': 692.5076, 'event_3': 83, 'event_4': 588, 'event_5': 6906, 'event_6': 482.499, 'event_7': 72.99423, 'event_8': 77.818634, 'event_9': 28.850437}, 'event_1': {'event_0': -88.36508, 'event_1': 0.4798174, 'event_2': 609.8974, 'event_3': 201.4345, 'event_4': 252.3303, 'event_5': -89.411736, 'event_6': 398.0249, 'event_7': -15.114546, 'event_8': -10.247231, 'event_9': -59.649944}, 'event_2': {'event_0': -742.774, 'event_1': -648.16595, 'event_2': 0.7838011, 'event_3': -434.17572, 'event_4': -379.97842, 'event_5': -743.8886, 'event_6': -224.83229, 'event_7': -664.7718, 'event_8': -659.58856, 'event_9': -712.1956}, 'event_3': {'event_0': -295.33624, 'event_1': -204.66805, 'event_2': 417.2522, 'event_3': 0.4094839, 'event_4': 52.348972, 'event_5': -296.40436, 'event_6': 201.03276, 'event_7': -220.58249, 'event_8': -215.61504, 'event_9': -266.03223}, 'event_4': {'event_0': -347.83484, 'event_1': -256.7053, 'event_2': 368.38712, 'event_3': -50.581696, 'event_4': 1.6230345, 'event_5': -348.9089, 'event_6': 151.06499, 'event_7': -272.6996, 'event_8': -267.7083, 'event_9': -318.38177}, 'event_5': {'event_0': 1.7285347, 'event_1': 89.78009, 'event_2': 693.7551, 'event_3': 288.94006, 'event_4': 339.3811, 'event_5': 0.69081783, 'event_6': 483.77454, 'event_7': 74.3252, 'event_8': 79.14901, 'event_9': 30.186771}, 'event_6': {'event_0': -506.04224, 'event_1': -413.51913, 'event_2': 221.12965, 'event_3': -204.24486, 'event_4': -151.24202, 'event_5': -507.133, 'event_6': 0.4851818, 'event_7': -429.75903, 'event_8': -424.69025, 'event_9': -476.13858}, 'event_7': {'event_0': -72.59607, 'event_1': 16.109943, 'event_2': 624.575, 'event_3': 216.74991, 'event_4': 267.56644, 'event_5': -73.64154, 'event_6': 413.03336, 'event_7': 0.5400181, 'event_8': 5.399585, 'event_9': -43.92624}, 'event_8': {'event_0': -77.65174, 'event_1': 11.098981, 'event_2': 619.8698, 'event_3': 211.84027, 'event_4': 262.68185, 'event_5': -78.697205, 'event_6': 408.22208, 'event_7': -4.478693, 'event_8': 0.38325787, 'event_9': -48.967598}, 'event_9': {'event_0': -27.953386, 'event_1': 60.359238, 'event_2': 666.1278, 'event_3': 260.1105, 'event_4': 310.70114, 'event_5': -28.994083, 'event_6': 455.52374, 'event_7': 44.858456, 'event_8': 49.696564, 'event_9': 0.58948994}}

rev_transference = {'event_0': {'event_0': 0.38802624, 'event_1': -88.36508, 'event_2': -742.774, 'event_3': -295.33624, 'event_4': -347.83484, 'event_5': 1.7285347, 'event_6': -506.04224, 'event_7': -72.59607, 'event_8': -77.65174, 'event_9': -27.953386}, 'event_1': {'event_0': 88.45151, 'event_1': 0.4798174, 'event_2': -648.16595, 'event_3': -204.66805, 'event_4': -256.7053, 'event_5': 89.78009, 'event_6': -413.51913, 'event_7': 16.109943, 'event_8': 11.098981, 'event_9': 60.359238}, 'event_2': {'event_0': 692.5076, 'event_1': 609.8974, 'event_2': 0.7838011, 'event_3': 417.2522, 'event_4': 368.38712, 'event_5': 693.7551, 'event_6': 221.12965, 'event_7': 624.575, 'event_8': 619.8698, 'event_9': 666.1278}, 'event_3': {'event_0': 287.6383, 'event_1': 201.4345, 'event_2': -434.17572, 'event_3': 0.4094839, 'event_4': -50.581696, 'event_5': 288.94006, 'event_6': -204.24486, 'event_7': 216.74991, 'event_8': 211.84027, 'event_9': 260.1105}, 'event_4': {'event_0': 338.08588, 'event_1': 252.3303, 'event_2': -379.97842, 'event_3': 52.348972, 'event_4': 1.6230345, 'event_5': 339.3811, 'event_6': -151.24202, 'event_7': 267.56644, 'event_8': 262.68185, 'event_9': 310.70114}, 'event_5': {'event_0': -0.6496906, 'event_1': -89.411736, 'event_2': -743.8886, 'event_3': -296.40436, 'event_4': -348.9089, 'event_5': 0.69081783, 'event_6': -507.133, 'event_7': -73.64154, 'event_8': -78.697205, 'event_9': -28.994083}, 'event_6': {'event_0': 482.499, 'event_1': 398.0249, 'event_2': -224.83229, 'event_3': 201.03276, 'event_4': 151.06499, 'event_5': 483.77454, 'event_6': 0.4851818, 'event_7': 413.03336, 'event_8': 408.22208, 'event_9': 455.52374}, 'event_7': {'event_0': 72.99423, 'event_1': -15.114546, 'event_2': -664.7718, 'event_3': -220.58249, 'event_4': -272.6996, 'event_5': 74.3252, 'event_6': -429.75903, 'event_7': 0.5400181, 'event_8': -4.478693, 'event_9': 44.858456}, 'event_8': {'event_0': 77.818634, 'event_1': -10.247231, 'event_2': -659.58856, 'event_3': -215.61504, 'event_4': -267.7083, 'event_5': 79.14901, 'event_6': -424.69025, 'event_7': 5.399585, 'event_8': 0.38325787, 'event_9': 49.696564}, 'event_9': {'event_0': 28.850437, 'event_1': -59.649944, 'event_2': -712.1956, 'event_3': -266.03223, 'event_4': -318.38177, 'event_5': 30.186771, 'event_6': -476.13858, 'event_7': -43.92624, 'event_8': -48.967598, 'event_9': 0.58948994}}
